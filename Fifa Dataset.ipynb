# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Ma199\OneDrive\Documents\data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df['Penalties']
# Out:
# 0        75.0
# 1        85.0
# 2        81.0
# 3        40.0
# 4        79.0
#          ...
# 18202    43.0
# 18203    43.0
# 18204    55.0
# 18205    50.0
# 18206    33.0
# Name: Penalties, Length: 18207, dtype: float64

# %%
# View each column individually
for col in df.columns:
    print(df[ 'Penalties' ])
    # You can also perform other operations on each column here
# Out:
# 0        75.0
# 1        85.0
# 2        81.0
# 3        40.0
# 4        79.0
#          ...
# 18202    43.0
# 18203    43.0
# 18204    55.0
# 18205    50.0
# 18206    33.0
# Name: Penalties, Length: 18207, dtype: float64
# 0        75.0
# 1        85.0
# 2        81.0
# 3        40.0
# 4        79.0
#          ...
# 18202    43.0
# 18203    43.0
# 18204    55.0
# 18205    50.0
# 18206    33.0
# Name: Penalties, Length: 18207, dtype: float64
# 0        75.0
# 1        85.0
# 2        81.0
# 3        40.0
# 4        79.0
#          ...
# 18202    43.0
# 18203    43.0
# 18204    55.0
# 18205    50.0
# 18206    33.0
# Name: Penalties, Length: 18207, dtype: float64
# 0        75.0
# 1        85.0
# 2        81.0
# 3        40.0
# 4        79.0
#          ...
# 18202    43.0
# 18203    43.0
# 18204    55.0
# 18205    50.0
# 18206    33.0
# Name: Penalties, Length: 18207, dtype: float64
# 0        75.0
# 1        85.0
# 2        81.0
# 3        40.0
# 4        79.0
#          ...
# ...

# %%
df.corr().max()
# Out:
# Unnamed: 0                  1.0
# ID                          1.0
# Age                         1.0
# Overall                     1.0
# Potential                   1.0
# Special                     1.0
# International Reputation    1.0
# Weak Foot                   1.0
# Skill Moves                 1.0
# Jersey Number               1.0
# Crossing                    1.0
# Finishing                   1.0
# HeadingAccuracy             1.0
# ShortPassing                1.0
# Volleys                     1.0
# Dribbling                   1.0
# Curve                       1.0
# FKAccuracy                  1.0
# LongPassing                 1.0
# BallControl                 1.0
# Acceleration                1.0
# SprintSpeed                 1.0
# Agility                     1.0
# Reactions                   1.0
# Balance                     1.0
# ShotPower                   1.0
# Jumping                     1.0
# Stamina                     1.0
# Strength                    1.0
# ...

# %%
df.corr().min()
# Out:
# Unnamed: 0                 -0.972791
# ID                         -0.739208
# Age                        -0.739208
# Overall                    -0.972791
# Potential                  -0.633395
# Special                    -0.674637
# International Reputation   -0.413322
# Weak Foot                  -0.233098
# Skill Moves                -0.621925
# Jersey Number              -0.241156
# Crossing                   -0.663053
# Finishing                  -0.588752
# HeadingAccuracy            -0.750417
# ShortPassing               -0.729785
# Volleys                    -0.590808
# Dribbling                  -0.754625
# Curve                      -0.606286
# FKAccuracy                 -0.556605
# LongPassing                -0.596820
# BallControl                -0.788444
# Acceleration               -0.594866
# SprintSpeed                -0.599694
# Agility                    -0.528899
# Reactions                  -0.832156
# Balance                    -0.506102
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
df.isna().mean()
# Out:
# Unnamed: 0        0.000000
# ID                0.000000
# Name              0.000000
# Age               0.000000
# Photo             0.000000
#                     ...
# GKHandling        0.002636
# GKKicking         0.002636
# GKPositioning     0.002636
# GKReflexes        0.002636
# Release Clause    0.085901
# Length: 89, dtype: float64

# %%
df.isna()
# Out:
#        Unnamed: 0     ID   Name    Age  Photo  Nationality   Flag  Overall  \
# 0           False  False  False  False  False        False  False    False
# 1           False  False  False  False  False        False  False    False
# 2           False  False  False  False  False        False  False    False
# 3           False  False  False  False  False        False  False    False
# 4           False  False  False  False  False        False  False    False
# ...           ...    ...    ...    ...    ...          ...    ...      ...
# 18202       False  False  False  False  False        False  False    False
# 18203       False  False  False  False  False        False  False    False
# 18204       False  False  False  False  False        False  False    False
# 18205       False  False  False  False  False        False  False    False
# 18206       False  False  False  False  False        False  False    False
#
#        Potential   Club  ...  Composure  Marking  StandingTackle  \
# ...

# %% [markdown]
# #Age: Age can be an important factor in evaluating a player's performance, as younger players may have higher potential for improvement and longevity in their career.
#
# #Overall Rating: Overall rating is a key performance metric in the dataset and can provide an overall assessment of a player's skill level.
#
# #Potential: Potential indicates a player's expected future performance, and can be used to identify young players with high growth potential.
#
# #Preferred Foot: Preferred foot can affect a player's playing style and performance, as some players may be more comfortable with their left or right foot.
#
# #Position: Position can be crucial in analyzing a player's role and performance on the field, as different positions require different skill sets and attributes.
#
# #Club: Club affiliation can provide information about a player's current team and league, which can be relevant in analyzing a player's performance in a specific league or team.
#
# #Value and Wage: Monetary variables such as value and wage can provide insights into a player's market value and earnings, which can be relevant in assessing a player's financial impact and marketability.

# %%
sns.histplot('Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming `df` is your DataFrame with an 'age' column
# Create age ranges with 5-year gaps
age_ranges = range(df['Age'].min(), df['Age'].max() + 6, 5)
labels = [f"{i}-{i+4}" for i in age_ranges[:-1]]
df['Age_range'] = pd.cut(df['Age'], bins=age_ranges, labels=labels)

# Create histogram with age ranges
plt.hist(df['Age'], bins=age_ranges, edgecolor='black', alpha=0.75)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution with 5-Year Gap')

# Add total number on top of bars
for i in range(len(age_ranges) - 1):
    count = df['Age_range'].value_counts().sort_index()[labels[i]]
    plt.text(age_ranges[i] + 2.5, count + 2, str(count), ha='center')

plt.show()

# %%
sns.countplot(x='Potential',data=df)
# Out:
# <AxesSubplot:xlabel='Potential', ylabel='count'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `df` is your DataFrame with a 'Potential' column
# Create potential ranges with a gap of 10
potential_ranges = range(df['Potential'].min(), df['Potential'].max() + 11, 10)
labels = [f"{i}-{i+9}" for i in potential_ranges[:-1]]
df['Potential_range'] = pd.cut(df['Potential'], bins=potential_ranges, labels=labels)

# Specify figure size
fig, ax = plt.subplots(figsize=(8, 6))

# Create histogram with potential ranges using Seaborn
sns.histplot(df, x='Potential', hue='Potential_range', bins=potential_ranges, edgecolor='black', alpha=0.75)
plt.xlabel('Potential')
plt.ylabel('Frequency')
plt.title('Potential Distribution with 10-Point Gap')
plt.legend(title='Potential Range')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `df` is your DataFrame with a 'Preferred Foot' column

# Create count plot
sns.countplot(x='Preferred Foot', data=df)

# Add labels and title
plt.xlabel('Preferred Foot')
plt.ylabel('Count')
plt.title('Preferred Foot Distribution')

plt.show()

# %%
s = df['Club'].value_counts()

# %%
s.max()
# Out:
# 33

# %%
s.min()
# Out:
# 18

# %%
s = df['Club'].value_counts()

plt.figure(figsize=(12, 6))  # set the figure size

# create a bar chart using seaborn
sns.barplot(x=s.index, y=s.values)
plt.xticks(rotation=90)  # rotate x-axis labels for better readability
plt.xlabel('Club')
plt.ylabel('Count')
plt.title('Value Counts of Club Column')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the value counts of 'Club' column
s = df['Club'].value_counts()

# Filter the top 15 teams
top_15_teams = s.head(15)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_15_teams.index, y=top_15_teams.values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Club')
plt.ylabel('Count')
plt.title('Top 15 Clubs by Count')
plt.show()

# %%
s = df['Club'].value_counts()

# Filter the top 15 teams
top_15_teams = s.tail(15)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_15_teams.index, y=top_15_teams.values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Club')
plt.ylabel('Count')
plt.title('Top 15 Clubs by Count')
# Out:
# Text(0.5, 1.0, 'Top 15 Clubs by Count')

# %%
num_clubs = df['Club'].nunique()
print("Number of clubs in the data:", num_clubs)
# Out:
# Number of clubs in the data: 651

# %%
club_counts = df['Club'].value_counts()
print(club_counts)
# Out:
# FC Barcelona                 33
# Valencia CF                  33
# Fortuna Düsseldorf           33
# Cardiff City                 33
# Rayo Vallecano               33
#                              ..
# América FC (Minas Gerais)    20
# Fluminense                   20
# Sligo Rovers                 19
# Limerick FC                  19
# Derry City                   18
# Name: Club, Length: 651, dtype: int64

# %%
# List of columns to drop
columns_to_drop = ['ID', 'StandingTackle', 'SlidingTackle', 'Jersey Number', 'Composure', 'Marking', 'Jumping', 'Flag',
                   'Photo', 'Club Logo', 'Real Face', 'Joined', 'Loaned From', 'Contract Valid Until', 'Nationality',
                   'Skill Moves', 'Release Clause', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
                   'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']

# Drop the columns from DataFrame
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# Verify columns are dropped
print("Columns after dropping: ", df.columns)


                


#Age: Age can be an important factor in evaluating a player's performance, as younger players may have higher potential for improvement and longevity in their career.

#Overall Rating: Overall rating is a key performance metric in the dataset and can provide an overall assessment of a player's skill level.

#Potential: Potential indicates a player's expected future performance, and can be used to identify young players with high growth potential.

#Preferred Foot: Preferred foot can affect a player's playing style and performance, as some players may be more comfortable with their left or right foot.

#Position: Position can be crucial in analyzing a player's role and performance on the field, as different positions require different skill sets and attributes.

#Club: Club affiliation can provide information about a player's current team and league, which can be relevant in analyzing a player's performance in a specific league or team.

#Value and Wage: Monetary variables such as value and wage can provide insights into a player's market value and earnings, which can be relevant in assessing a player's financial impact and marketability.
# Out:
# Columns after dropping:  Index(['Unnamed: 0', 'Name', 'Age', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Age_range',
#        'Potential_range'],
#       dtype='object')

# %%
# Drop a single column
df.drop('Club', axis=1, inplace=True)

# %%
df['Position']
# Out:
# 0         RF
# 1         ST
# 2         LW
# 3         GK
# 4        RCM
#         ...
# 18202     CM
# 18203     ST
# 18204     ST
# 18205     RW
# 18206     CM
# Name: Position, Length: 18207, dtype: object

# %%
df['Position'].isna().value_counts()
# Out:
# False    18147
# True        60
# Name: Position, dtype: int64

# %%
most_occurred_foot = df['Position'].value_counts().idxmax()

# Replace null values with the most occurred foot
df['Position'].fillna(most_occurred_foot, inplace=True)

# Update the value counts after filling null values
s = df['Position'].value_counts()

# %%
df
# Out:
#        Unnamed: 0                Name  Age  Overall  Potential    Value  \
# 0               0            L. Messi   31       94         94  €110.5M
# 1               1   Cristiano Ronaldo   33       94         94     €77M
# 2               2           Neymar Jr   26       92         93  €118.5M
# 3               3              De Gea   27       91         93     €72M
# 4               4        K. De Bruyne   27       91         92    €102M
# ...           ...                 ...  ...      ...        ...      ...
# 18202       18202        J. Lundstram   19       47         65     €60K
# 18203       18203  N. Christoffersson   19       47         63     €60K
# 18204       18204           B. Worman   16       47         67     €60K
# 18205       18205      D. Walker-Rice   17       47         66     €60K
# 18206       18206           G. Nugent   16       46         66     €60K
#
#         Wage  Special Preferred Foot  International Reputation  ...  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Name                          object
# Age                            int64
# Overall                        int64
# Potential                      int64
# Value                         object
# Wage                          object
# Special                        int64
# Preferred Foot                object
# International Reputation     float64
# Weak Foot                    float64
# Work Rate                     object
# Body Type                     object
# Position                      object
# Height                        object
# Weight                        object
# Crossing                     float64
# Finishing                    float64
# HeadingAccuracy              float64
# ShortPassing                 float64
# Volleys                      float64
# Dribbling                    float64
# Curve                        float64
# FKAccuracy                   float64
# LongPassing                  float64
# ...

# %%
df['Positioning']
# Out:
# 0        94.0
# 1        95.0
# 2        89.0
# 3        12.0
# 4        87.0
#          ...
# 18202    39.0
# 18203    46.0
# 18204    48.0
# 18205    44.0
# 18206    34.0
# Name: Positioning, Length: 18207, dtype: float64

# %%
df
# Out:
#        Unnamed: 0                Name  Age  Overall  Potential    Value  \
# 0               0            L. Messi   31       94         94  €110.5M
# 1               1   Cristiano Ronaldo   33       94         94     €77M
# 2               2           Neymar Jr   26       92         93  €118.5M
# 3               3              De Gea   27       91         93     €72M
# 4               4        K. De Bruyne   27       91         92    €102M
# ...           ...                 ...  ...      ...        ...      ...
# 18202       18202        J. Lundstram   19       47         65     €60K
# 18203       18203  N. Christoffersson   19       47         63     €60K
# 18204       18204           B. Worman   16       47         67     €60K
# 18205       18205      D. Walker-Rice   17       47         66     €60K
# 18206       18206           G. Nugent   16       46         66     €60K
#
#         Wage  Special Preferred Foot  International Reputation  ...  \
# ...

# %%
df.isna().mean()
# Out:
# Unnamed: 0                  0.000000
# Name                        0.000000
# Age                         0.000000
# Overall                     0.000000
# Potential                   0.000000
# Value                       0.000000
# Wage                        0.000000
# Special                     0.000000
# Preferred Foot              0.002636
# International Reputation    0.002636
# Weak Foot                   0.002636
# Work Rate                   0.002636
# Body Type                   0.002636
# Position                    0.000000
# Height                      0.002636
# Weight                      0.002636
# Crossing                    0.002636
# Finishing                   0.002636
# HeadingAccuracy             0.002636
# ShortPassing                0.002636
# Volleys                     0.002636
# Dribbling                   0.002636
# Curve                       0.002636
# FKAccuracy                  0.002636
# LongPassing                 0.002636
# ...

# %%
df['Preferred Foot'].isna().value_counts()
# Out:
# False    18159
# True        48
# Name: Preferred Foot, dtype: int64

# %%
# Assuming s is the value counts of 'Preferred Foot'
# Assuming df is the dataframe with the relevant data

# Get the most occurred foot
most_occurred_foot = df['Preferred Foot'].value_counts().idxmax()

# Replace null values with the most occurred foot
df['Preferred Foot'].fillna(most_occurred_foot, inplace=True)

# Update the value counts after filling null values
s = df['Preferred Foot'].value_counts()

# %%
df['International Reputation'].isna().value_counts()
# Out:
# False    18159
# True        48
# Name: International Reputation, dtype: int64

# %%
mean_international_reputation = df['International Reputation'].mean()

# Replace NaN values with the mean
df['International Reputation'].fillna(mean_international_reputation, inplace=True)

# Update the value counts after filling NaN values
s = df['International Reputation'].value_counts()

# %%
df['Weak Foot'].isna().value_counts()
# Out:
# False    18159
# True        48
# Name: Weak Foot, dtype: int64

# %%
mean_international_reputation = df['Weak Foot'].mean()

# Replace NaN values with the mean
df['Weak Foot'].fillna(mean_international_reputation, inplace=True)

# Update the value counts after filling NaN values
s = df['Weak Foot'].value_counts()

# %%
df['HeadingAccuracy'].isna().value_counts()
# Out:
# False    18159
# True        48
# Name: HeadingAccuracy, dtype: int64

# %%
mean_international_reputation = df['HeadingAccuracy'].mean()

# Replace NaN values with the mean
df['HeadingAccuracy'].fillna(mean_international_reputation, inplace=True)

# Update the value counts after filling NaN values
s = df['HeadingAccuracy'].value_counts()

# %%
df['Work Rate'].isna().value_counts()
# Out:
# False    18159
# True        48
# Name: Work Rate, dtype: int64

# %%
most_workrate = df['Work Rate'].value_counts().idxmax()

# Replace null values with the most occurred foot
df['Work Rate'].fillna(most_occurred_foot, inplace=True)

# Update the value counts after filling null values
s = df['Work Rate'].value_counts()

# %%
df['Body Type'].isna().value_counts()
# Out:
# False    18159
# True        48
# Name: Body Type, dtype: int64

# %%
most_workrate = df['Body Type'].value_counts().idxmax()

# Replace null values with the most occurred foot
df['Body Type'].fillna(most_occurred_foot, inplace=True)

# Update the value counts after filling null values
s = df['Body Type'].value_counts()

# %%
df['Height']
# Out:
# 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object

# %%
df['Height'].isna().value_counts()
# Out:
# False    18159
# True        48
# Name: Height, dtype: int64

# %%
s = df['International Reputation'].value_counts()

plt.figure(figsize=(12, 6))  # set the figure size

# create a bar chart using seaborn
ax=sns.barplot(x=s.index, y=s.values)
plt.xticks(rotation=90)  # rotate x-axis labels for better readability
plt.xlabel('International Reputation')
plt.ylabel('Count')
plt.title('Value Counts of International Reputation')
for i, v in enumerate(s.values):
    ax.text(i, v/2, str(v), ha='center', va='bottom', fontweight='bold')
plt.show()

# %%
top5_reputation = df['International Reputation'].nlargest(5)

# %%
top5_reputation
# Out:
# 0     5.0
# 1     5.0
# 2     5.0
# 7     5.0
# 22    5.0
# Name: International Reputation, dtype: float64

# %%
import pandas as pd

# Load dataset
df = pd.read_csv(r"C:\Users\Ma199\OneDrive\Documents\data.csv")

# Identify columns with NaN values
columns_with_nan = df.columns[df.isna().sum() > 0]

# Calculate the mean
mean_values = df.mean()

# Fill NaN values with mean
df.fillna(mean_values, inplace=True)

# Display updated DataFrame
print(df)
# Out:
# C:\Users\Ma199\AppData\Local\Temp\ipykernel_8800\659462949.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_values = df.mean()
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
# ...

# %%
df.isna().value_counts()
# Out:
# Unnamed: 0  ID     Name   Age    Photo  Nationality  Flag   Overall  Potential  Club   Club Logo  Value  Wage   Special  Preferred Foot  International Reputation  Weak Foot  Skill Moves  Work Rate  Body Type  Real Face  Position  Jersey Number  Joined  Loaned From  Contract Valid Until  Height  Weight  LS     ST     RS     LW     LF     CF     RF     RW     LAM    CAM    RAM    LM     LCM    CM     RCM    RM     LWB    LDM    CDM    RDM    RWB    LB     LCB    CB     RCB    RB     Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  Release Clause
# ...

# %%
df.isna().mean()
# Out:
# Unnamed: 0        0.000000
# ID                0.000000
# Name              0.000000
# Age               0.000000
# Photo             0.000000
#                     ...
# GKHandling        0.000000
# GKKicking         0.000000
# GKPositioning     0.000000
# GKReflexes        0.000000
# Release Clause    0.085901
# Length: 89, dtype: float64

# %%
columns_to_drop = ['ID', 'StandingTackle', 'SlidingTackle', 'Jersey Number', 'Composure', 'Marking', 'Jumping', 'Flag',
                   'Photo', 'Club Logo', 'Real Face', 'Joined', 'Loaned From', 'Contract Valid Until', 'Nationality',
                   'Skill Moves', 'Release Clause', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
                   'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']

# Drop the columns from DataFrame
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# Verify columns are dropped
print("Columns after dropping: ", df.columns)
# Out:
# Columns after dropping:  Index(['Unnamed: 0', 'Name', 'Age', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     18207 non-null  object
#  7   Wage                      18207 non-null  object
#  8   Special                   18207 non-null  int64
#  9   Preferred Foot            18159 non-null  object
#  10  International Reputation  18207 non-null  float64
#  11  Weak Foot                 18207 non-null  float64
#  12  Work Rate                 18159 non-null  object
# ...

# %%
categorical_columns = df.select_dtypes(include='object').columns
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      18207 non-null  object
#  6   Value                     18207 non-null  object
#  7   Wage                      18207 non-null  object
#  8   Special                   18207 non-null  int64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18207 non-null  float64
#  11  Weak Foot                 18207 non-null  float64
#  12  Work Rate                 18207 non-null  object
# ...

# %%
df.isna().value_counts().sum()
# Out:
# 18207

# %%
import pandas as pd

# Load DataFrame
  # Replace with your actual DataFrame

# Define columns to convert to numeric
columns_to_convert = ['Value', 'Wage', 'Height', 'Weight']  # Replace with column names to be converted

# Loop through columns and convert to numeric
for col in columns_to_convert:
    # Remove non-numeric characters from column values
    df[col] = df[col].str.replace('[^\d.]', '', regex=True)
    # Convert column to float
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Print updated data types of columns
print(df[columns_to_convert].dtypes)
# Out:
# Value     float64
# Wage        int64
# Height      int64
# Weight      int64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['Stamina','SprintSpeed','HeadingAccuracy','LongShots']], df['Overall'], test_size=0.25, random_state=1)

model = LinearRegression()
model.fit(x_train, y_train)

score = model.score(x_test, y_test)
print('model score', score)

# Make predictions on new data
new_data = pd.DataFrame({'Stamina': [1, 2], 'SprintSpeed': [3, 4], 'HeadingAccuracy': [5, 6], 'LongShots': [7, 8]})
predictions = model.predict(new_data)

print('Predictions:', predictions)
# Out:
# model score 0.21598654929366945
# Predictions: [58.30231403 58.48186473]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
# Define the dependent variable (y) and independent variables (x1, x2, x3)
y = df['Overall']
x1 = df['GKDiving']
x2 = df['GKHandling']
x3 = df['GKKicking']
x4 = df['GKPositioning']
x5 = df['GKReflexes']
x6 = df['Penalties']

# Combine the independent variables into a DataFrame
X = pd.DataFrame({'GKDiving': x1, 'GKHandling': x2, 'GKKicking': x3, 'GKPositioning': x4, 'GKReflexes': x5, 'Penalties': x6})

# Drop any rows with missing values
X = X.dropna()

# Add a constant term to the independent variables to represent the intercept
X = sm.add_constant(X)

# Create the OLS regression model
model = sm.OLS(y, X)

# Fit the model
results = model.fit()

# Print the summary statistics
print(results.summary())

# Make predictions on new data
new_data = pd.DataFrame({'GKDiving': [1, 2], 'GKHandling': [3, 4], 'GKKicking': [5, 6], 'GKPositioning': [7, 8], 'GKReflexes': [9, 10], 'Penalties': [11, 12]})
new_data = sm.add_constant(new_data)
predictions = results.predict(new_data)

print('Predictions:', predictions)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Overall   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     654.5
# Date:                Sun, 21 May 2023   Prob (F-statistic):               0.00
# Time:                        19:31:40   Log-Likelihood:                -59246.
# No. Observations:               18207   AIC:                         1.185e+05
# Df Residuals:                   18200   BIC:                         1.186e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            52.7230      0.230    229.246      0.000      52.272      53.174
# ...
